# %%
import cv2

# %% [markdown]
# -- to load the image or read the image--

# %%
img = cv2.imread('code.jpeg',-1)

# %% [markdown]
# --pixel values of 1st row--

# %%
print( img[0])
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
# ...

# %% [markdown]
# --also you get your values using slicing--

# %%
print( img[157][45:400])
# Out:
# [[255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [255 255 255]
#  [251 255 254]
#  [240 252 246]
#  [241 251 245]
#  [254 252 252]
#  [255 253 255]
#  [255 239 246]
#  [110  79  86]
#  [ 93  43  47]
#  [221 173 172]
#  [169 142 132]
#  [ 94  84  67]
#  [101  97  78]
#  [102  88  70]
#  [150 100  94]
#  [ 75  15  16]
#  [143  97 103]
#  [255 245 246]
#  [224 205 198]
#  [221 207 195]
#  [222 208 196]
#  [225 211 199]
#  [229 215 203]
#  [235 221 209]
#  [240 226 214]
#  [244 230 218]
#  [238 224 212]
#  [240 226 214]
#  [241 227 215]
#  [236 222 210]
#  [228 214 202]
#  [223 209 197]
#  [223 209 197]
#  [226 212 200]
#  [228 211 202]
#  [228 211 202]
#  [228 211 202]
#  [228 211 202]
#  [228 211 202]
#  [228 211 202]
#  [228 211 202]
# ...
